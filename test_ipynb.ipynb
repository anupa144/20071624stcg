# %%
supplies = ["Pens", "Pencils", "Notebooks"]
quantities = {"Pens": 10, "Pencils": 20, "Notebooks": 5}
categories = {"Writing", "Stationery"}

print("Quantities before update")
print(quantities)
quantities["Pens"] += 15
print("Quantities after update")
print(quantities)

result =  ((quantities["Pencils"])> 10) and ((quantities["Notebooks"])> 10) 
print("Value is " + str(result) + " for Pencils is greater than Notebooks ")

if "Pens" in supplies:
    print("Pens found in supplies")
else:
    print("Pens not found in supplies")

if "Stationery" in categories:
    print("Stationery found in categories")
else:
    print("Stationery not found in categories")

supplies = ["Pens", "Pencils", "Notebooks"]
quantities = {"Pens": 10, "Pencils": 20, "Notebooks": 5}
categories = {"Writing", "Stationery"}

print("Quantities before update")
print(quantities)
quantities["Pens"] += 15
print("Quantities after update")
print(quantities)

result =  ((quantities["Pencils"])> 10) and ((quantities["Notebooks"])> 10) 
print("Value is " + str(result) + " for Pencils is greater than Notebooks ")

if "Pens" in supplies:
    print("Pens found in supplies")
else:
    print("Pens not found in supplies")

if "Stationery" in categories:
    print("Stationery found in categories")
else:
    print("Stationery not found in categories")
# Out:
# Quantities before update
# {'Pens': 10, 'Pencils': 20, 'Notebooks': 5}
# Quantities after update
# {'Pens': 25, 'Pencils': 20, 'Notebooks': 5}
# Value is False for Pencils is greater than Notebooks
# Pens found in supplies
# Stationery found in categories
# Quantities before update
# {'Pens': 10, 'Pencils': 20, 'Notebooks': 5}
# Quantities after update
# {'Pens': 25, 'Pencils': 20, 'Notebooks': 5}
# Value is False for Pencils is greater than Notebooks
# Pens found in supplies
# Stationery found in categories
